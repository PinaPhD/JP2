# %% [markdown]
# ## Investigating the dependability of SDN-enabled IoT-uRLLC networks in large-scale offshore wind farms
# ![image.png](attachment:image.png)

# %%
#Defining the network architecture states and failure modes
